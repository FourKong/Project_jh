# %%
pip install mord
# Out:
# Collecting mord
#   Downloading mord-0.7.tar.gz (8.6 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: mord
#   Building wheel for mord (setup.py) ... done
#   Created wheel for mord: filename=mord-0.7-py3-none-any.whl size=9885 sha256=b1ff573204d55f6c28b25289a138f8fbca2a2b11844f6e66f6c2d3b1073d6aa7
#   Stored in directory: /root/.cache/pip/wheels/77/00/19/3cea86fbfc737ec4acb515cd94497dcc33f943fa157548b96c
# Successfully built mord
# Installing collected packages: mord
# Successfully installed mord-0.7

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder
from mord import LogisticIT
from sklearn.metrics import accuracy_score
import pandas as pd
from google.colab import drive
import joblib

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/final_data.csv')
X = file.drop(['sat_all', 'pid'], axis=1)
y = file['sat_all']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)
model = LogisticIT()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
coefficients = model.coef_
feature_names = X.columns

for i, coefficient in enumerate(coefficients):
    feature = feature_names[i]
    print(f"Feature: {feature}, Coefficient: {coefficient}")
# Out:
# Accuracy: 0.6630727762803235
# Feature: sex, Coefficient: 0.20472896448332922
# Feature: age, Coefficient: -0.04792675544422077
# Feature: about_marriage, Coefficient: 0.08005828212520023
# Feature: marriage, Coefficient: -0.10808225613328255
# Feature: car, Coefficient: -0.1645618452450319
# Feature: house, Coefficient: -0.9914107207357788
# Feature: parents, Coefficient: -0.16134743114939634
# Feature: live_alone, Coefficient: -0.5176440839227124
# Feature: house_form, Coefficient: -0.004123325239252934
# Feature: house_rental, Coefficient: -0.04625761793718489
# Feature: health, Coefficient: 0.15957709055224
# Feature: body, Coefficient: -0.0332378681452828
# Feature: exercise, Coefficient: 0.10191940106599334
# Feature: work_life, Coefficient: -0.049940379956317824
# Feature: real_dream, Coefficient: -0.0982278110682724
# Feature: result_procedure, Coefficient: 0.12656921354587392
# Feature: individual_group, Coefficient: 0.033846849640486815
# Feature: me_other, Coefficient: -0.17818085216723378
# Feature: for_happinese, Coefficient: 0.060115610633893264
# Feature: edu, Coefficient: 0.2743072306152445
# Feature: int_family, Coefficient: -0.0669057141693784
# Feature: int_friend, Coefficient: 0.01816637817851658
# Feature: int_other, Coefficient: -0.01401775459577721
# Feature: sat_living, Coefficient: 0.28107300752418557
# Feature: sat_health, Coefficient: 0.05063893590503391
# Feature: sat_achieve, Coefficient: 0.5871921390204088
# Feature: sat_human, Coefficient: 0.8630170133486152

# %%
file = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/final_data.csv')
X = file.drop(['sat_all', 'sat_achieve', 'pid'], axis=1)
y = file['sat_all']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=16)
model = LogisticIT()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
coefficients = model.coef_
feature_names = X.columns

for i, coefficient in enumerate(coefficients):
    feature = feature_names[i]
    print(f"Feature: {feature}, Coefficient: {coefficient}")

# model 객체를 저장
joblib.dump(model, 'all_model.pkl')

# %%
file = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/final_data.csv')
file = file.drop(['sat_all', 'sat_human', 'sat_achieve', 'sat_health', 'pid'], axis=1)
X = file.drop('sat_living', axis=1)
y = file['sat_living']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=21)
model = LogisticIT()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
coefficients = model.coef_
feature_names = X.columns

for i, coefficient in enumerate(coefficients):
    feature = feature_names[i]
    print(f"Feature: {feature}, Coefficient: {coefficient}")

# model 객체를 저장
joblib.dump(model, 'living_model.pkl')

# %%
file = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/final_data.csv')
file = file.drop(['sat_all', 'sat_human', 'sat_achieve', 'sat_living', 'pid'], axis=1)
X = file.drop('sat_health', axis=1)
y = file['sat_health']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.65, random_state=3)
model = LogisticIT()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

coefficients = model.coef_
feature_names = X.columns

for i, coefficient in enumerate(coefficients):
    feature = feature_names[i]
    print(f"Feature: {feature}, Coefficient: {coefficient}")

# model 객체를 저장
joblib.dump(model, 'health_model.pkl')

# %%
file = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/final_data.csv')
file = file.drop(['sat_all', 'sat_human', 'sat_health', 'sat_living', 'pid'], axis=1)
X = file.drop('sat_achieve', axis=1)
y = file['sat_achieve']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=8)
model = LogisticIT()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

coefficients = model.coef_
feature_names = X.columns

for i, coefficient in enumerate(coefficients):
    feature = feature_names[i]
    print(f"Feature: {feature}, Coefficient: {coefficient}")

# %%
file = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/final_data.csv')
file = file.drop(['sat_all', 'sat_achieve', 'sat_health', 'sat_living', 'pid'], axis=1)
X = file.drop('sat_human', axis=1)
y = file['sat_human']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=3)
model = LogisticIT()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

coefficients = model.coef_
feature_names = X.columns

for i, coefficient in enumerate(coefficients):
    feature = feature_names[i]
    print(f"Feature: {feature}, Coefficient: {coefficient}")

# model 객체를 저장
joblib.dump(model, 'human_model.pkl')

# %%
file = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/final_data.csv')
file = file.loc[:,['sat_all', 'sat_health', 'sat_living', 'sat_human']]
X = file.drop('sat_all', axis=1)
y = file['sat_all']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=33)
model = LogisticIT()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# %%
file = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/final_data.csv')
X = file.drop(['sat_all', 'sat_living', 'sat_health', 'sat_human','sat_achieve', 'pid'], axis=1)
datas = ['all', 'living', 'health', 'human']
df_result = pd.DataFrame()
for feature in X.columns :
  header = pd.DataFrame([f'{feature}'])
  df_result = pd.concat((df_result, header), ignore_index=True)
df_result = pd.concat((df_result, pd.DataFrame(['sat'])), ignore_index=True)
index=0
for a in datas:
    a_model = joblib.load(f'/content/drive/MyDrive/Colab Notebooks/{a}_model.pkl')
    df = pd.DataFrame({'feature': [], 'coef': []})

    for feature, coefficient in zip(X.columns, a_model.coef_):
        df2 = pd.DataFrame({'feature': [feature], 'coef': [coefficient]})
        df = pd.concat((df, df2), ignore_index=True)

    df3 = pd.DataFrame({'feature': ['sat'], 'coef': [index+10]})
    df = pd.concat((df, df3), ignore_index=True)
    df_result = pd.concat((df_result, df['coef']), ignore_index=True, axis=1, join='inner')
    index = index + 1

df_result = df_result.round(3)
print(df_result.T)
df_result.T.to_excel(excel_writer='coef_data.xlsx', index=False, header=False)
# Out:
#       0      1               2         3      4      5        6           7   \
# 0    sex    age  about_marriage  marriage    car  house  parents  live_alone
# 1  0.188  0.045             0.0    -0.129 -0.037 -0.995   -0.125       -0.69
# 2  0.059 -0.151          -0.236     1.082 -0.862 -1.356    0.445       0.127
# 3 -0.151 -0.036          -0.095     0.307  0.009 -0.104    0.018       0.104
# 4 -0.134 -0.189          -0.177     0.653 -0.679  0.619    0.698       0.333
#
#            8             9   ...          14                15  \
# 0  house_form  house_rental  ...  real_dream  result_procedure
# 1       0.039        -0.068  ...      -0.085             0.132
# 2       0.028          0.21  ...        0.01             0.059
# 3        0.03        -0.091  ...      -0.062             0.019
# 4      -0.043         0.358  ...      -0.134            -0.058
#
#                  16        17             18     19          20          21  \
# 0  individual_group  me_other  for_happinese    edu  int_family  int_friend
# 1             0.035    -0.164          0.063  0.239      -0.143       0.059
# 2             0.078    -0.076          0.044  0.114      -0.024       0.005
# 3            -0.026    -0.021           0.02  0.026      -0.029       0.096
# 4             0.103    -0.101           0.01  0.077      -0.037      -0.131
#
#           22    23
# 0  int_other   sat
# 1     -0.067  10.0
# 2     -0.056  11.0
# 3     -0.144  12.0
# 4     -0.204  13.0
#
# [5 rows x 24 columns]

# %%
model
# Out:
# LogisticIT()
